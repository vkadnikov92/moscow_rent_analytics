# %% [markdown]
# # Анализ данных по оценке аренды недвижимости Москвы ##

# %% [markdown]
# ### Прочтем наш DataSet

# %%
import pandas as pd
import matplotlib
df = pd.read_csv('/Users/cobalt/Desktop/ds_bootcamp/kv/_data.csv')

# %% [markdown]
# ### Предварительный просмотр данных

# %% [markdown]
# Unnamed: 0                    int64
# ID  объявления                int64
# Количество комнат            object
# Тип                          object
# Метро                        object
# Адрес                        object
# Площадь, м2                  object
# Дом                          object
# Парковка                     object
# Цена                         object
# Телефоны                     object
# Описание                     object
# Ремонт                       object
# Площадь комнат, м2           object
# Балкон                       object
# Окна                         object
# Санузел                      object
# Можно с детьми/животными     object
# Дополнительно                object
# Название ЖК                  object
# Серия дома                   object
# Высота потолков, м          float64
# Лифт                         object
# Мусоропровод                 object
# Ссылка на объявление         object

# %% [markdown]
# ### Анализируем что большенство данных представляеться в виде строк, посмотрим часть в табличном виде

# %%
df
# Out:
#        Unnamed: 0  ID  объявления Количество комнат       Тип  \
# 0               0       271271157                 4  Квартира
# 1               1       271634126                 4  Квартира
# 2               2       271173086   4, Оба варианта  Квартира
# 3               3       272197456   4, Оба варианта  Квартира
# 4               4       273614615                 2  Квартира
# ...           ...             ...               ...       ...
# 23363       23363       215565511               NaN  Квартира
# 23364       23364       274654844                 1  Квартира
# 23365       23365       268679909   2, Оба варианта  Квартира
# 23366       23366       274807525                 2  Квартира
# 23367       23367       274672243   2, Оба варианта  Квартира
#
#                               Метро  \
# 0      м. Смоленская (9 мин пешком)
# 1      м. Смоленская (8 мин пешком)
# 2      м. Смоленская (7 мин пешком)
# 3      м. Смоленская (3 мин пешком)
# ...

# %% [markdown]
# ### Понимаем примерную структуру и объём данных

# %% [markdown]
# Индексы и первая колонка идентичны
# Название колонок кирелические
# Проанализируем колонки которые мы можем удалить например колонки которые содержат минимальное количество данных
# Проверим нет ли в наших данных других городов, если есть то удалим
